# %%
# Lab Week 7 - Classification tasks with different types of features
# This file has small examples that are meant to be run individually
#   in the Python shell

import nltk

# define a feature extraction function for each name
def gender_features(word):
    return{'last_letter': word[-1]}

print(gender_features('Shrek'))

# resource for male and female first names
from nltk.corpus import names
print(names.words('male.txt')[:20])
print(names.words('female.txt')[:20])

# make list of male and female names paired with gender
namesgender = ([(name, 'male') for name in names.words('male.txt')] +
          [(name, 'female') for name in names.words('female.txt')])
print(len(namesgender))
print(namesgender[:20])
print(namesgender[7924:])

# put the list into random order
import random
random.shuffle(namesgender)
print(namesgender[:20])

# separate the names into training and test
train_names = namesgender[500:]
test_names = namesgender[:500]



# use our features to train a classify and test on the development test set
train_set = [(gender_features(n), g) for (n, g) in train_names]
test_set = [(gender_features(n), g) for (n, g) in test_names]
print(train_set[:20])

classifier = nltk.NaiveBayesClassifier.train(train_set)

# classify new instances
print(classifier.classify(gender_features('Neo')))
print(classifier.classify(gender_features('Trinity')))

# classify accuracy function runs the classifier on the test set and reports
#   comparisons between predicted labels and actual/gold labels
print(nltk.classify.accuracy(classifier, test_set))


# this function available for naive bayes classifiers
print(classifier.show_most_informative_features(20))


# define a function that will compare the classifier labels with the gold standard labels
def geterrors(test):
    errors = []
    for (name, tag) in test:
        guess = classifier.classify(gender_features(name))
        if guess != tag:
            errors.append( (tag, guess, name) )
    return errors

errors = geterrors(test_names)
print(len(errors))

# define a function to print the errors
def printerrors(errors):
    for (tag, guess, name) in sorted(errors):
        print('correct={:<8s} guess={:<8s} name={:<30s}'.format(tag, guess, name))

printerrors(errors)



## classify part of speech based on sentence context
from nltk.corpus import brown

# define features for the "i"th word in the sentence, including three types of suffix 
#     and one pre-word
# the pos features function takes the sentence of untagged words and the index of a word i
#   it creates features for word i, including the previous word i-1
def pos_features(sentence, i):    
    features = {"suffix(1)": sentence[i][-1:],
		    "suffix(2)": sentence[i][-2:],
		    "suffix(3)": sentence[i][-3:]}
    if i == 0:
        features["prev-word"] = "<START>"
    else:
        features["prev-word"] = sentence[i-1]
    return features 

# look at features of a specific word in a specific sentence
# first sentence of brown corpus
sentence0 = brown.sents()[0]
print(sentence0)
# word 8 of sentence 0
print(sentence0[8])

# pos features of the word 8 
print(pos_features(sentence0, 8))

# get the POS tagged sentences with categories of news
tagged_sents = brown.tagged_sents(categories='news')
tag_sent0 = tagged_sents[0]
tag_sent0

# the function nltk.tag.untag will take the tags off
nltk.tag.untag(tag_sent0)

# the python enumerate function generates an index number for each item in a list
for i,(word,tag) in enumerate(tag_sent0):
    print (i, word, tag)

# get feature sets of words appearing in the corpus, from untagged sentences.
# and then get their tags from corresponding tagged sentence
# use the Python function enumerate to pair the index numbers with sentence words 
#   for the pos features function
featuresets = []
for tagged_sent in tagged_sents:
	untagged_sent = nltk.tag.untag(tagged_sent)
	for i, (word, tag) in enumerate(tagged_sent):
		featuresets.append( (pos_features(untagged_sent, i), tag) )

# look at the feature sets of the first 10 words
for f in featuresets[:10]:
	print (f)
	
# using naive Bayesian as classifier
# split data into a training set and a test set, using a 90%/10% split
size = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[size:], featuresets[:size]
print(len(train_set))
print(len(test_set))

# train classifier on the training set
classifier = nltk.NaiveBayesClassifier.train(train_set)

# evaluate the accuracy (this will take a little while)
print(nltk.classify.accuracy(classifier, test_set))
# the result is reasonable for features without the previous tag


### classify documents based on keywords
from nltk.corpus import movie_reviews
import random

# movie reviews are labeled either positive or negative (by human annotators)
print(movie_reviews.categories())

# for each document in movie_reviews, get its words and category (positive/negative)
documents = [(list(movie_reviews.words(fileid)), category)
              for category in movie_reviews.categories()
              for fileid in movie_reviews.fileids(category)]
print(len(documents))

random.shuffle(documents)
# look at the first document - consists of a list of all the words in the review
# followed by the category
print(documents[0])

## use words from all documents to define the word vector for features
# get all words from all movie_reviews and put into a frequency distribution
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
print(len(all_words))

# get the 2000 most frequently appearing keywords in the corpus
word_items = all_words.most_common(2000)
word_features = [word for (word, freq) in word_items]   # just the words

# look at the first 100 words
print(word_features[:100])

# define features (keywords) of a document
# each feature is 'contains(keyword)' and is true or false depending
# on whether that keyword is in the document
def document_features(document, word_features):
	document_words = set(document)
	features = {}
	for word in word_features:
		features['V_%s' % word] = (word in document_words)
	return features

# get features sets for a document, including keyword features and category feature
featuresets = [(document_features(d, word_features), c) for (d,c) in documents]

# the feature sets are 2000 words long - so this is optional
print(featuresets[0])

# training using naive Baysian classifier with a 95/5 split
train_set, test_set = featuresets[100:], featuresets[:100]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# evaluate the accuracy of the classifier
print (nltk.classify.accuracy(classifier, test_set))
# the accuracy result may vary since we randomized the documents

# show which features of classifier are most informative
print(classifier.show_most_informative_features(30))
# Out:
# {'last_letter': 'k'}
# ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot', 'Abbott', 'Abby', 'Abdel', 'Abdul', 'Abdulkarim', 'Abdullah', 'Abe', 'Abel', 'Abelard', 'Abner', 'Abraham', 'Abram', 'Ace', 'Adair', 'Adam']
# ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abby', 'Abigael', 'Abigail', 'Abigale', 'Abra', 'Acacia', 'Ada', 'Adah', 'Adaline', 'Adara', 'Addie', 'Addis', 'Adel', 'Adela']
# 7944
# [('Aamir', 'male'), ('Aaron', 'male'), ('Abbey', 'male'), ('Abbie', 'male'), ('Abbot', 'male'), ('Abbott', 'male'), ('Abby', 'male'), ('Abdel', 'male'), ('Abdul', 'male'), ('Abdulkarim', 'male'), ('Abdullah', 'male'), ('Abe', 'male'), ('Abel', 'male'), ('Abelard', 'male'), ('Abner', 'male'), ('Abraham', 'male'), ('Abram', 'male'), ('Ace', 'male'), ('Adair', 'male'), ('Adam', 'male')]
# [('Zena', 'female'), ('Zenia', 'female'), ('Zia', 'female'), ('Zilvia', 'female'), ('Zita', 'female'), ('Zitella', 'female'), ('Zoe', 'female'), ('Zola', 'female'), ('Zonda', 'female'), ('Zondra', 'female'), ('Zonnya', 'female'), ('Zora', 'female'), ('Zorah', 'female'), ('Zorana', 'female'), ('Zorina', 'female'), ('Zorine', 'female'), ('Zsa Zsa', 'female'), ('Zsazsa', 'female'), ('Zulema', 'female'), ('Zuzana', 'female')]
# [('Rodney', 'male'), ('Lonee', 'female'), ('Edythe', 'female'), ('Shaun', 'female'), ('Terina', 'female'), ('Neda', 'female'), ('Keelia', 'female'), ('Bernie', 'female'), ('Carrol', 'female'), ('Nanine', 'female'), ('Tove', 'female'), ('Kellia', 'female'), ('Ira', 'male'), ('Trudey', 'female'), ('Kia', 'female'), ('Zulema', 'female'), ('Betty', 'female'), ('Calhoun', 'male'), ('Catie', 'female'), ('Shandie', 'female')]
# [({'last_letter': 'o'}, 'male'), ({'last_letter': 'd'}, 'male'), ({'last_letter': 'l'}, 'male'), ({'last_letter': 'u'}, 'female'), ({'last_letter': 'i'}, 'female'), ({'last_letter': 'w'}, 'male'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'y'}, 'male'), ({'last_letter': 'y'}, 'female'), ({'last_letter': 'o'}, 'male'), ({'last_letter': 'h'}, 'male'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'y'}, 'male'), ({'last_letter': 't'}, 'female'), ({'last_letter': 'e'}, 'female'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'l'}, 'male'), ({'last_letter': 'e'}, 'female'), ({'last_letter': 'h'}, 'male')]
# male
# female
# 0.744
# Most Informative Features
#              last_letter = 'a'            female : male   =     38.4 : 1.0
#              last_letter = 'k'              male : female =     32.1 : 1.0
#              last_letter = 'p'              male : female =     20.8 : 1.0
#              last_letter = 'f'              male : female =     15.9 : 1.0
#              last_letter = 'v'              male : female =     11.1 : 1.0
#              last_letter = 'd'              male : female =     10.0 : 1.0
#              last_letter = 'm'              male : female =      8.8 : 1.0
#              last_letter = 'o'              male : female =      8.2 : 1.0
#              last_letter = 'r'              male : female =      6.7 : 1.0
#              last_letter = 'w'              male : female =      6.6 : 1.0
#              last_letter = 'g'              male : female =      4.7 : 1.0
#              last_letter = 'z'              male : female =      4.3 : 1.0
#              last_letter = 's'              male : female =      4.3 : 1.0
#              last_letter = 't'              male : female =      4.0 : 1.0
#              last_letter = 'j'              male : female =      3.9 : 1.0
#              last_letter = 'i'            female : male   =      3.9 : 1.0
#              last_letter = 'u'              male : female =      3.8 : 1.0
#              last_letter = 'b'              male : female =      3.3 : 1.0
#              last_letter = 'n'              male : female =      2.1 : 1.0
#              last_letter = 'x'              male : female =      2.1 : 1.0
# None
# 128
# correct=female   guess=male     name=Abagail
# correct=female   guess=male     name=Ambur
# correct=female   guess=male     name=Arabel
# correct=female   guess=male     name=Arleen
# correct=female   guess=male     name=Astrix
# correct=female   guess=male     name=Bell
# correct=female   guess=male     name=Beryl
# correct=female   guess=male     name=Caitrin
# correct=female   guess=male     name=Caroljean
# correct=female   guess=male     name=Carrol
# correct=female   guess=male     name=Chad
# correct=female   guess=male     name=Charlot
# correct=female   guess=male     name=Cherlyn
# correct=female   guess=male     name=Christal
# correct=female   guess=male     name=Christel
# correct=female   guess=male     name=Clem
# correct=female   guess=male     name=Clovis
# correct=female   guess=male     name=Corabel
# correct=female   guess=male     name=Cris
# correct=female   guess=male     name=Denys
# correct=female   guess=male     name=Dian
# correct=female   guess=male     name=Dido
# correct=female   guess=male     name=Drew
# correct=female   guess=male     name=Erin
# correct=female   guess=male     name=Fran
# correct=female   guess=male     name=Frances
# correct=female   guess=male     name=Gates
# correct=female   guess=male     name=Glynnis
# correct=female   guess=male     name=Gwyn
# correct=female   guess=male     name=Isabeau
# correct=female   guess=male     name=Jan
# correct=female   guess=male     name=Janet
# correct=female   guess=male     name=Jennifer
# correct=female   guess=male     name=Jewel
# correct=female   guess=male     name=Joell
# correct=female   guess=male     name=Joyan
# correct=female   guess=male     name=Kaitlynn
# correct=female   guess=male     name=Karlen
# correct=female   guess=male     name=Kip
# correct=female   guess=male     name=Koren
# correct=female   guess=male     name=Laureen
# correct=female   guess=male     name=Lian
# correct=female   guess=male     name=Madelin
# correct=female   guess=male     name=Margaux
# correct=female   guess=male     name=Mellicent
# correct=female   guess=male     name=Mildrid
# correct=female   guess=male     name=Nat
# correct=female   guess=male     name=Orel
# correct=female   guess=male     name=Phylys
# correct=female   guess=male     name=Rachael
# correct=female   guess=male     name=Raquel
# correct=female   guess=male     name=Rhiamon
# correct=female   guess=male     name=Ruthann
# correct=female   guess=male     name=Ryann
# correct=female   guess=male     name=Shaun
# correct=female   guess=male     name=Starlin
# correct=female   guess=male     name=Stoddard
# correct=female   guess=male     name=Susan
# correct=female   guess=male     name=Val
# correct=female   guess=male     name=Vivyan
# correct=female   guess=male     name=Wileen
# correct=male     guess=female   name=Adolphe
# correct=male     guess=female   name=Alexei
# correct=male     guess=female   name=Allie
# correct=male     guess=female   name=Ambrose
# correct=male     guess=female   name=Aristotle
# correct=male     guess=female   name=Arvy
# correct=male     guess=female   name=Barney
# correct=male     guess=female   name=Bartholemy
# correct=male     guess=female   name=Bartolomei
# correct=male     guess=female   name=Bela
# correct=male     guess=female   name=Boniface
# correct=male     guess=female   name=Boyce
# correct=male     guess=female   name=Brodie
# correct=male     guess=female   name=Burnaby
# correct=male     guess=female   name=Chane
# correct=male     guess=female   name=Charlie
# correct=male     guess=female   name=Chaunce
# correct=male     guess=female   name=Christy
# correct=male     guess=female   name=Clemente
# correct=male     guess=female   name=Demetre
# correct=male     guess=female   name=Dominique
# correct=male     guess=female   name=Drake
# correct=male     guess=female   name=Emmery
# correct=male     guess=female   name=Etienne
# correct=male     guess=female   name=Felipe
# correct=male     guess=female   name=Frankie
# correct=male     guess=female   name=French
# correct=male     guess=female   name=Gabe
# correct=male     guess=female   name=Gabriele
# correct=male     guess=female   name=Gene
# correct=male     guess=female   name=Georgy
# correct=male     guess=female   name=Giovanni
# correct=male     guess=female   name=Giuseppe
# correct=male     guess=female   name=Heath
# correct=male     guess=female   name=Heinrich
# correct=male     guess=female   name=Ira
# correct=male     guess=female   name=Irvine
# correct=male     guess=female   name=Jose
# correct=male     guess=female   name=Judah
# correct=male     guess=female   name=Lorrie
# correct=male     guess=female   name=Maddy
# correct=male     guess=female   name=Marve
# correct=male     guess=female   name=Merry
# correct=male     guess=female   name=Monty
# correct=male     guess=female   name=Morrie
# correct=male     guess=female   name=Mose
# correct=male     guess=female   name=Myke
# correct=male     guess=female   name=Ozzy
# correct=male     guess=female   name=Piggy
# correct=male     guess=female   name=Quiggly
# correct=male     guess=female   name=Quincey
# correct=male     guess=female   name=Roarke
# correct=male     guess=female   name=Rodney
# correct=male     guess=female   name=Rufe
# correct=male     guess=female   name=Seth
# correct=male     guess=female   name=Shea
# correct=male     guess=female   name=Sidney
# correct=male     guess=female   name=Siffre
# correct=male     guess=female   name=Stevy
# correct=male     guess=female   name=Stinky
# correct=male     guess=female   name=Tate
# correct=male     guess=female   name=Vasily
# correct=male     guess=female   name=Ware
# correct=male     guess=female   name=Willi
# correct=male     guess=female   name=Willy
# correct=male     guess=female   name=Yehudi
# correct=male     guess=female   name=Zacharia
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.']
# investigation
# {'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ion', 'prev-word': 'an'}
# 0 The AT
# 1 Fulton NP-TL
# 2 County NN-TL
# 3 Grand JJ-TL
# 4 Jury NN-TL
# 5 said VBD
# 6 Friday NR
# 7 an AT
# 8 investigation NN
# 9 of IN
# 10 Atlanta's NP$
# 11 recent JJ
# 12 primary NN
# 13 election NN
# 14 produced VBD
# 15 `` ``
# 16 no AT
# 17 evidence NN
# 18 '' ''
# 19 that CS
# 20 any DTI
# 21 irregularities NNS
# 22 took VBD
# 23 place NN
# 24 . .
# ({'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'The', 'prev-word': '<START>'}, 'AT')
# ({'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ton', 'prev-word': 'The'}, 'NP-TL')
# ({'suffix(1)': 'y', 'suffix(2)': 'ty', 'suffix(3)': 'nty', 'prev-word': 'Fulton'}, 'NN-TL')
# ({'suffix(1)': 'd', 'suffix(2)': 'nd', 'suffix(3)': 'and', 'prev-word': 'County'}, 'JJ-TL')
# ({'suffix(1)': 'y', 'suffix(2)': 'ry', 'suffix(3)': 'ury', 'prev-word': 'Grand'}, 'NN-TL')
# ({'suffix(1)': 'd', 'suffix(2)': 'id', 'suffix(3)': 'aid', 'prev-word': 'Jury'}, 'VBD')
# ({'suffix(1)': 'y', 'suffix(2)': 'ay', 'suffix(3)': 'day', 'prev-word': 'said'}, 'NR')
# ({'suffix(1)': 'n', 'suffix(2)': 'an', 'suffix(3)': 'an', 'prev-word': 'Friday'}, 'AT')
# ({'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ion', 'prev-word': 'an'}, 'NN')
# ({'suffix(1)': 'f', 'suffix(2)': 'of', 'suffix(3)': 'of', 'prev-word': 'investigation'}, 'IN')
# 90499
# 10055
# 0.7891596220785678
# ['neg', 'pos']
# 2000
# (['a', 'remake', 'of', 'the', '1978', 'warren', 'beatty', 'vehicle', '"', 'heaven', 'can', 'wait', '"', '(', 'which', 'in', 'turn', 'was', 'a', 'remake', 'of', '"', 'here', 'comes', 'mr', '.', 'jordan', '"', ')', ',', '"', 'down', 'to', 'earth', '"', 'tells', 'the', 'tale', 'of', 'lance', 'barton', '(', 'chris', 'rock', ',', '"', 'lethal', 'weapon', 'iv', '"', ')', ',', 'a', 'young', 'black', 'standup', 'comic', 'trying', 'to', 'win', 'over', 'the', 'audience', 'at', 'harlem', "'", 's', 'apollo', 'theater', '.', 'when', 'he', "'", 's', 'taken', 'to', 'heaven', 'prematurely', 'by', 'bumbling', 'angel', 'keyes', '(', 'eugene', 'levy', ',', '"', 'best', 'in', 'show', '"', ')', ',', 'his', 'only', 'recourse', 'is', 'to', 'return', 'in', 'another', 'body', '.', 'he', 'chooses', 'that', 'of', 'charles', 'wellington', ',', 'the', 'tenth', 'richest', 'man', 'in', 'the', 'united', 'states', '.', 'of', 'course', ',', 'wellington', 'is', 'not', 'only', 'rich', ',', 'but', 'white', 'and', '53', 'years', 'old', ',', 'which', 'makes', 'lance', "'", 's', 'bid', 'for', 'closing', 'night', 'at', 'the', 'apollo', ',', 'as', 'well', 'as', 'his', 'desire', 'to', 'woo', 'suntee', '(', 'regina', 'taylor', ',', '"', 'jerry', 'maguire', '"', ')', ',', 'a', 'tad', 'tricky', '.', 'the', 'original', 'elaine', 'may', '/', 'warren', 'beatty', 'script', 'has', 'been', 'reworked', 'by', 'chris', 'rock', ',', 'lance', 'crouther', ',', 'ali', 'leroi', ',', 'and', 'louis', 'c', '.', 'k', '.', 'to', 'turn', 'beatty', "'", 's', 'vehicle', 'as', 'a', 'football', 'player', 'into', 'rock', "'", 's', 'vehicle', 'as', 'a', 'comic', 'and', 'add', 'some', 'racial', 'humor', '.', 'as', 'directed', 'by', 'chris', 'weitz', 'and', 'paul', 'weitz', '(', 'codirectors', 'of', '"', 'american', 'pie', '"', 'and', 'costars', 'of', '"', 'chuck', '&', 'buck', '"', ')', ',', 'the', 'whole', 'affair', 'comes', 'off', 'as', 'amateur', 'hour', '.', 'initial', 'scenes', 'play', 'like', 'filmed', 'line', 'reading', 'rehearsals', '.', 'production', 'values', 'are', 'shoddy', '.', 'most', 'serious', 'of', 'all', 'is', 'the', 'use', 'of', 'rock', 'when', 'his', 'wellington', 'counterpart', 'would', 'have', 'been', 'more', 'appropriate', '.', 'this', 'problem', 'is', 'clearly', 'attributable', 'to', 'the', 'fact', 'that', 'the', 'old', 'white', 'guy', 'is', 'never', 'lip', 'or', 'action', 'synched', 'when', 'he', 'is', 'on', 'screen', '.', 'rock', 'does', 'get', 'the', 'chance', 'to', 'do', 'some', 'fun', 'schtick', ',', 'such', 'as', 'his', 'turnaround', 'on', 'wellington', "'", 's', 'plans', 'for', 'a', 'poor', 'neighborhood', 'hospital', '(', "'", 'bullet', 'in', 'the', 'head', '?', 'you', 'got', 'a', 'bed', '!', "'", ')', ',', 'but', 'he', "'", 's', 'uneven', 'when', 'interacting', 'with', 'the', 'rest', 'of', 'the', 'cast', '.', 'regina', 'taylor', 'fares', 'well', 'amidst', 'the', 'mediocrity', 'as', 'the', 'young', 'activist', 'who', 'confusedly', 'ends', 'up', 'falling', 'for', 'the', 'man', 'she', 'believed', 'to', 'be', 'her', 'nemesis', '.', 'also', 'good', 'is', 'frankie', 'faison', '(', '"', 'hannibal', '"', ')', 'as', 'whitney', ',', 'lance', "'", 's', 'compassionate', 'manager', '-', 'the', 'only', 'human', 'who', "'", 's', 'made', 'privy', 'to', 'lance', "'", 's', 'body', 'body', 'switch', '.', 'chaz', 'palminteri', 'and', 'levy', 'are', 'pretty', 'much', 'wasted', 'as', 'heaven', "'", 's', 'ambassadors', '.', 'another', '"', 'best', 'in', 'show', '"', 'alumnus', ',', 'jennifer', 'coolidge', ',', 'is', 'poorly', 'used', 'as', 'wellington', "'", 's', 'cheating', 'wife', '(', 'and', 'shown', 'several', 'days', 'apart', 'wearing', 'the', 'same', 'outfit', '?', '!', ')', 'and', 'greg', 'germann', '(', 'tv', "'", 's', '"', 'ally', 'mcbeal', ',', '"', '"', 'sweet', 'november', '"', ')', 'continues', 'display', 'his', 'sitcom', 'roots', 'as', 'her', 'lover', 'and', 'husband', "'", 's', 'lawyer', '.', 'mark', 'addy', '(', '"', 'the', 'full', 'monty', '"', ')', 'is', 'sorely', 'under ...
# 39768
# [',', 'the', '.', 'a', 'and', 'of', 'to', "'", 'is', 'in', 's', '"', 'it', 'that', '-', ')', '(', 'as', 'with', 'for', 'his', 'this', 'film', 'i', 'he', 'but', 'on', 'are', 't', 'by', 'be', 'one', 'movie', 'an', 'who', 'not', 'you', 'from', 'at', 'was', 'have', 'they', 'has', 'her', 'all', '?', 'there', 'like', 'so', 'out', 'about', 'up', 'more', 'what', 'when', 'which', 'or', 'she', 'their', ':', 'some', 'just', 'can', 'if', 'we', 'him', 'into', 'even', 'only', 'than', 'no', 'good', 'time', 'most', 'its', 'will', 'story', 'would', 'been', 'much', 'character', 'also', 'get', 'other', 'do', 'two', 'well', 'them', 'very', 'characters', ';', 'first', '--', 'after', 'see', '!', 'way', 'because', 'make', 'life']
# ({'V_,': True, 'V_the': True, 'V_.': True, 'V_a': True, 'V_and': True, 'V_of': True, 'V_to': True, "V_'": True, 'V_is': True, 'V_in': True, 'V_s': True, 'V_"': True, 'V_it': False, 'V_that': True, 'V_-': True, 'V_)': True, 'V_(': True, 'V_as': True, 'V_with': True, 'V_for': True, 'V_his': True, 'V_this': True, 'V_film': False, 'V_i': False, 'V_he': True, 'V_but': True, 'V_on': True, 'V_are': True, 'V_t': False, 'V_by': True, 'V_be': True, 'V_one': False, 'V_movie': False, 'V_an': False, 'V_who': True, 'V_not': True, 'V_you': True, 'V_from': False, 'V_at': True, 'V_was': True, 'V_have': True, 'V_they': False, 'V_has': True, 'V_her': True, 'V_all': True, 'V_?': True, 'V_there': False, 'V_like': True, 'V_so': False, 'V_out': False, 'V_about': False, 'V_up': True, 'V_more': True, 'V_what': False, 'V_when': True, 'V_which': True, 'V_or': True, 'V_she': True, 'V_their': False, 'V_:': False, 'V_some': True, 'V_just': False, 'V_can': True, 'V_if': False, 'V_we': False, 'V_him': False, 'V_into': True, 'V_even': False, 'V_only': True, 'V_than': False, 'V_no': False, 'V_good': True, 'V_time': False, 'V_most': True, 'V_its': False, 'V_will': False, 'V_story': False, 'V_would': True, 'V_been': True, 'V_much': True, 'V_character': False, 'V_also': True, 'V_get': True, 'V_other': False, 'V_do': True, 'V_two': False, 'V_well': True, 'V_them': False, 'V_very': False, 'V_characters': False, 'V_;': False, 'V_first': False, 'V_--': False, 'V_after': False, 'V_see': False, 'V_!': True, 'V_way': False, 'V_because': False, 'V_make': False, 'V_life': False, 'V_off': True, 'V_too': False, 'V_any': False, 'V_does': True, 'V_really': False, 'V_had': False, 'V_while': False, 'V_films': False, 'V_how': False, 'V_plot': False, 'V_little': False, 'V_where': False, 'V_people': False, 'V_over': True, 'V_could': False, 'V_then': False, 'V_me': False, 'V_scene': True, 'V_man': True, 'V_bad': False, 'V_my': False, 'V_never': True, 'V_being': False, 'V_best': True, 'V_these': False, 'V_don': False, 'V_new': False, 'V_doesn': False, 'V_scenes': True, 'V_many': False, 'V_director': False, 'V_such': True, 'V_know': False, 'V_were': False, 'V_movies': False, 'V_through': False, 'V_here': True, 'V_action': True, 'V_great': False, 'V_re': False, 'V_another': True, 'V_love': False, 'V_go': True, 'V_made': True, 'V_us': False, 'V_big': False, 'V_end': False, 'V_something': False, 'V_back': False, 'V_*': False, 'V_still': False, 'V_world': False, 'V_seems': False, 'V_work': False, 'V_those': False, 'V_makes': True, 'V_now': False, 'V_before': False, 'V_however': False, 'V_between': False, 'V_few': False, 'V_/': True, 'V_down': True, 'V_every': True, 'V_though': False, 'V_better': False, 'V_real': False, 'V_audience': True, 'V_enough': False, 'V_seen': False, 'V_take': False, 'V_around': False, 'V_both': False, 'V_going': False, 'V_year': False, 'V_performance': False, 'V_why': False, 'V_should': True, 'V_role': False, 'V_isn': False, 'V_same': True, 'V_old': True, 'V_gets': False, 'V_your': False, 'V_may': True, 'V_things': False, 'V_think': False, 'V_years': True, 'V_last': False, 'V_comedy': False, 'V_funny': False, 'V_actually': False, 'V_ve': False, 'V_long': False, 'V_look': False, 'V_almost': False, 'V_own': False, 'V_thing': False, 'V_fact': True, 'V_nothing': False, 'V_say': False, 'V_right': False, 'V_john': False, 'V_although': False, 'V_played': False, 'V_find': False, 'V_script': True, 'V_come': False, 'V_ever': False, 'V_cast': True, 'V_since': False, 'V_did': False, 'V_star': False, 'V_plays': False, 'V_young': True, 'V_show': True, 'V_comes': True, 'V_m': False, 'V_part': False, 'V_original': True, 'V_actors': False, 'V_screen': True, 'V_without': False, 'V_again': False, 'V_acting': False, 'V_three': False, 'V_day': False, 'V_each': False, 'V_point': False, 'V_lot': False, 'V_least': False, 'V_takes': False, 'V_guy': True, 'V_quite': False, 'V_himself': False, 'V_away': False, 'V_during': False, 'V_family': False, 'V_effects': False, 'V_course': True, 'V_g ...
# 0.82
# Most Informative Features
#            V_outstanding = True              pos : neg    =     11.0 : 1.0
#                  V_mulan = True              pos : neg    =      9.0 : 1.0
#                 V_seagal = True              neg : pos    =      8.2 : 1.0
#            V_wonderfully = True              pos : neg    =      6.8 : 1.0
#                  V_damon = True              pos : neg    =      5.9 : 1.0
#                   V_lame = True              neg : pos    =      5.6 : 1.0
#                  V_awful = True              neg : pos    =      5.4 : 1.0
#                 V_wasted = True              neg : pos    =      5.3 : 1.0
#             V_ridiculous = True              neg : pos    =      5.2 : 1.0
#                 V_poorly = True              neg : pos    =      5.1 : 1.0
#                  V_waste = True              neg : pos    =      5.0 : 1.0
#                  V_flynt = True              pos : neg    =      5.0 : 1.0
#                  V_worst = True              neg : pos    =      4.5 : 1.0
#                V_unfunny = True              neg : pos    =      4.5 : 1.0
#                    V_era = True              pos : neg    =      4.3 : 1.0
#                  V_bland = True              neg : pos    =      4.2 : 1.0
#                   V_jedi = True              pos : neg    =      4.1 : 1.0
#                   V_dull = True              neg : pos    =      4.1 : 1.0
#                 V_allows = True              pos : neg    =      4.0 : 1.0
#              V_pointless = True              neg : pos    =      4.0 : 1.0
#              V_laughable = True              neg : pos    =      4.0 : 1.0
#              V_fantastic = True              pos : neg    =      4.0 : 1.0
#                   V_mess = True              neg : pos    =      3.9 : 1.0
#                 V_stupid = True              neg : pos    =      3.9 : 1.0
#              V_portrayal = True              pos : neg    =      3.8 : 1.0
#                 V_superb = True              pos : neg    =      3.7 : 1.0
#               V_terrific = True              pos : neg    =      3.6 : 1.0
#                 V_subtle = True              pos : neg    =      3.5 : 1.0
#              V_memorable = True              pos : neg    =      3.5 : 1.0
#                  V_badly = True              neg : pos    =      3.5 : 1.0
# None

# %% [markdown]
# # Part 1

# %%
def gender_features3(word):

    return {'suffix1': word[-1], 'suffix2': word[-2]}

# %%
gender_features3('Shrek')
# Out:
# {'suffix1': 'k', 'suffix2': 'e'}

# %%
# Lab Week 7 - Classification tasks with different types of features
# This file has small examples that are meant to be run individually
#   in the Python shell

import nltk

# define a feature extraction function for each name
def gender_features(word):
    return{'last_letter': word[-1]}

print(gender_features('Shrek'))

# resource for male and female first names
from nltk.corpus import names
print(names.words('male.txt')[:20])
print(names.words('female.txt')[:20])

# make list of male and female names paired with gender
namesgender = ([(name, 'male') for name in names.words('male.txt')] +
          [(name, 'female') for name in names.words('female.txt')])
print(len(namesgender))
print(namesgender[:20])
print(namesgender[7924:])

# put the list into random order
import random
random.shuffle(namesgender)
print(namesgender[:20])

# separate the names into training and test
train_names = namesgender[500:]
test_names = namesgender[:500]



# use our features to train a classify and test on the development test set
train_set = [(gender_features3(n), g) for (n, g) in train_names]
test_set = [(gender_features3(n), g) for (n, g) in test_names]
print(train_set[:20])

classifier = nltk.NaiveBayesClassifier.train(train_set)

# classify new instances
print(classifier.classify(gender_features('Neo')))
print(classifier.classify(gender_features('Trinity')))

# classify accuracy function runs the classifier on the test set and reports
#   comparisons between predicted labels and actual/gold labels
print(nltk.classify.accuracy(classifier, test_set))


# this function available for naive bayes classifiers
print(classifier.show_most_informative_features(20))


# define a function that will compare the classifier labels with the gold standard labels
def geterrors(test):
    errors = []
    for (name, tag) in test:
        guess = classifier.classify(gender_features(name))
        if guess != tag:
            errors.append( (tag, guess, name) )
    return errors

errors = geterrors(test_names)
print(len(errors))

# define a function to print the errors
def printerrors(errors):
    for (tag, guess, name) in sorted(errors):
        print('correct={:<8s} guess={:<8s} name={:<30s}'.format(tag, guess, name))

printerrors(errors)
# Out:
# {'last_letter': 'k'}
# ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot', 'Abbott', 'Abby', 'Abdel', 'Abdul', 'Abdulkarim', 'Abdullah', 'Abe', 'Abel', 'Abelard', 'Abner', 'Abraham', 'Abram', 'Ace', 'Adair', 'Adam']
# ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abby', 'Abigael', 'Abigail', 'Abigale', 'Abra', 'Acacia', 'Ada', 'Adah', 'Adaline', 'Adara', 'Addie', 'Addis', 'Adel', 'Adela']
# 7944
# [('Aamir', 'male'), ('Aaron', 'male'), ('Abbey', 'male'), ('Abbie', 'male'), ('Abbot', 'male'), ('Abbott', 'male'), ('Abby', 'male'), ('Abdel', 'male'), ('Abdul', 'male'), ('Abdulkarim', 'male'), ('Abdullah', 'male'), ('Abe', 'male'), ('Abel', 'male'), ('Abelard', 'male'), ('Abner', 'male'), ('Abraham', 'male'), ('Abram', 'male'), ('Ace', 'male'), ('Adair', 'male'), ('Adam', 'male')]
# [('Zena', 'female'), ('Zenia', 'female'), ('Zia', 'female'), ('Zilvia', 'female'), ('Zita', 'female'), ('Zitella', 'female'), ('Zoe', 'female'), ('Zola', 'female'), ('Zonda', 'female'), ('Zondra', 'female'), ('Zonnya', 'female'), ('Zora', 'female'), ('Zorah', 'female'), ('Zorana', 'female'), ('Zorina', 'female'), ('Zorine', 'female'), ('Zsa Zsa', 'female'), ('Zsazsa', 'female'), ('Zulema', 'female'), ('Zuzana', 'female')]
# [('Elinore', 'female'), ('Madonna', 'female'), ('Kitty', 'female'), ('Gill', 'male'), ('Salim', 'male'), ('Lorie', 'female'), ('Chandra', 'female'), ('Brandice', 'female'), ('Jan', 'male'), ('Claribel', 'female'), ('Elton', 'male'), ('Ansel', 'male'), ('Tobe', 'male'), ('Bridget', 'female'), ('Marge', 'female'), ('Emelina', 'female'), ('Deborah', 'female'), ('Bartholemy', 'male'), ('Danyette', 'female'), ('Josephus', 'male')]
# [({'suffix1': 'a', 'suffix2': 'l'}, 'female'), ({'suffix1': 'a', 'suffix2': 'l'}, 'female'), ({'suffix1': 'a', 'suffix2': 's'}, 'female'), ({'suffix1': 'e', 'suffix2': 'y'}, 'female'), ({'suffix1': 'n', 'suffix2': 'o'}, 'male'), ({'suffix1': 'd', 'suffix2': 'u'}, 'male'), ({'suffix1': 'e', 'suffix2': 'i'}, 'male'), ({'suffix1': 'e', 'suffix2': 'n'}, 'female'), ({'suffix1': 'a', 'suffix2': 'h'}, 'male'), ({'suffix1': 'e', 'suffix2': 'i'}, 'female'), ({'suffix1': 'l', 'suffix2': 'e'}, 'male'), ({'suffix1': 'y', 'suffix2': 'e'}, 'female'), ({'suffix1': 'l', 'suffix2': 'l'}, 'male'), ({'suffix1': 't', 'suffix2': 'o'}, 'male'), ({'suffix1': 'a', 'suffix2': 'r'}, 'female'), ({'suffix1': 'y', 'suffix2': 'd'}, 'male'), ({'suffix1': 'y', 'suffix2': 'd'}, 'female'), ({'suffix1': 'a', 'suffix2': 'k'}, 'female'), ({'suffix1': 's', 'suffix2': 's'}, 'male'), ({'suffix1': 'l', 'suffix2': 'a'}, 'male')]
# female
# female
# 0.744
# Most Informative Features
#                  suffix1 = 'a'            female : male   =     36.5 : 1.0
#                  suffix1 = 'k'              male : female =     32.5 : 1.0
#                  suffix1 = 'f'              male : female =     16.1 : 1.0
#                  suffix1 = 'p'              male : female =     12.0 : 1.0
#                  suffix1 = 'v'              male : female =     10.6 : 1.0
#                  suffix1 = 'd'              male : female =      9.9 : 1.0
#                  suffix1 = 'm'              male : female =      8.4 : 1.0
#                  suffix1 = 'o'              male : female =      8.4 : 1.0
#                  suffix2 = 'o'              male : female =      8.2 : 1.0
#                  suffix1 = 'r'              male : female =      7.1 : 1.0
#                  suffix2 = 'u'              male : female =      6.2 : 1.0
#                  suffix1 = 'g'              male : female =      5.5 : 1.0
#                  suffix2 = 'E'              male : female =      5.1 : 1.0
#                  suffix1 = 'w'              male : female =      4.8 : 1.0
#                  suffix1 = 'b'              male : female =      4.1 : 1.0
#                  suffix1 = 't'              male : female =      4.0 : 1.0
#                  suffix1 = 'z'              male : female =      4.0 : 1.0
#                  suffix1 = 'j'              male : female =      4.0 : 1.0
#                  suffix1 = 's'              male : female =      3.9 : 1.0
#                  suffix1 = 'u'              male : female =      3.9 : 1.0
# None
# 201
# correct=male     guess=female   name=Albert
# correct=male     guess=female   name=Allan
# correct=male     guess=female   name=Allyn
# correct=male     guess=female   name=Andy
# correct=male     guess=female   name=Ansel
# correct=male     guess=female   name=Ansell
# correct=male     guess=female   name=Antone
# correct=male     guess=female   name=Apostolos
# correct=male     guess=female   name=Aram
# correct=male     guess=female   name=Aristotle
# correct=male     guess=female   name=Augustus
# correct=male     guess=female   name=Aziz
# correct=male     guess=female   name=Bancroft
# correct=male     guess=female   name=Bartholemy
# correct=male     guess=female   name=Bearnard
# correct=male     guess=female   name=Billie
# correct=male     guess=female   name=Boris
# correct=male     guess=female   name=Brewster
# correct=male     guess=female   name=Calhoun
# correct=male     guess=female   name=Carroll
# correct=male     guess=female   name=Carsten
# correct=male     guess=female   name=Cat
# correct=male     guess=female   name=Chet
# correct=male     guess=female   name=Chevalier
# correct=male     guess=female   name=Clair
# correct=male     guess=female   name=Claude
# correct=male     guess=female   name=Collins
# correct=male     guess=female   name=Corky
# correct=male     guess=female   name=Corwin
# correct=male     guess=female   name=Cory
# correct=male     guess=female   name=Craig
# correct=male     guess=female   name=Curtis
# correct=male     guess=female   name=Cy
# correct=male     guess=female   name=Cyrille
# correct=male     guess=female   name=Darrell
# correct=male     guess=female   name=Demetri
# correct=male     guess=female   name=Derk
# correct=male     guess=female   name=Dickie
# correct=male     guess=female   name=Domenico
# correct=male     guess=female   name=Dunstan
# correct=male     guess=female   name=Elias
# correct=male     guess=female   name=Elton
# correct=male     guess=female   name=Emil
# correct=male     guess=female   name=Enrique
# correct=male     guess=female   name=Ernie
# correct=male     guess=female   name=Ethan
# correct=male     guess=female   name=Everard
# correct=male     guess=female   name=Fergus
# correct=male     guess=female   name=Filbert
# correct=male     guess=female   name=Filipe
# correct=male     guess=female   name=Fitzgerald
# correct=male     guess=female   name=Fleming
# correct=male     guess=female   name=Forbes
# correct=male     guess=female   name=Frazier
# correct=male     guess=female   name=Gardner
# correct=male     guess=female   name=Garvin
# correct=male     guess=female   name=Gasper
# correct=male     guess=female   name=Gay
# correct=male     guess=female   name=George
# correct=male     guess=female   name=Georges
# correct=male     guess=female   name=Gill
# correct=male     guess=female   name=Gregorio
# correct=male     guess=female   name=Hannibal
# correct=male     guess=female   name=Harold
# correct=male     guess=female   name=Hebert
# correct=male     guess=female   name=Henrie
# correct=male     guess=female   name=Henry
# correct=male     guess=female   name=Herby
# correct=male     guess=female   name=Hilton
# correct=male     guess=female   name=Hoyt
# correct=male     guess=female   name=Hugo
# correct=male     guess=female   name=Huntley
# correct=male     guess=female   name=Isaac
# correct=male     guess=female   name=Jan
# correct=male     guess=female   name=Jerrie
# correct=male     guess=female   name=Jerrome
# correct=male     guess=female   name=Jessey
# correct=male     guess=female   name=Johan
# correct=male     guess=female   name=Josephus
# correct=male     guess=female   name=Juanita
# correct=male     guess=female   name=Julie
# correct=male     guess=female   name=Kip
# correct=male     guess=female   name=Krishna
# correct=male     guess=female   name=Lambert
# correct=male     guess=female   name=Lars
# correct=male     guess=female   name=Laurance
# correct=male     guess=female   name=Leon
# correct=male     guess=female   name=Leopold
# correct=male     guess=female   name=Levy
# correct=male     guess=female   name=Lind
# correct=male     guess=female   name=Mac
# correct=male     guess=female   name=Mahmud
# correct=male     guess=female   name=Maison
# correct=male     guess=female   name=Manfred
# correct=male     guess=female   name=Mattie
# correct=male     guess=female   name=Matty
# correct=male     guess=female   name=Maurise
# correct=male     guess=female   name=Merrel
# correct=male     guess=female   name=Micheal
# correct=male     guess=female   name=Mickie
# correct=male     guess=female   name=Milo
# correct=male     guess=female   name=Mohammed
# correct=male     guess=female   name=Monroe
# correct=male     guess=female   name=Montgomery
# correct=male     guess=female   name=Moshe
# correct=male     guess=female   name=Nevin
# correct=male     guess=female   name=Niall
# correct=male     guess=female   name=Nickolas
# correct=male     guess=female   name=Noach
# correct=male     guess=female   name=Noam
# correct=male     guess=female   name=Normand
# correct=male     guess=female   name=Ollie
# correct=male     guess=female   name=Orbadiah
# correct=male     guess=female   name=Orlando
# correct=male     guess=female   name=Orson
# correct=male     guess=female   name=Orville
# correct=male     guess=female   name=Osbourne
# correct=male     guess=female   name=Paige
# correct=male     guess=female   name=Pascal
# correct=male     guess=female   name=Pasquale
# correct=male     guess=female   name=Patrick
# correct=male     guess=female   name=Pincus
# correct=male     guess=female   name=Plato
# correct=male     guess=female   name=Pooh
# correct=male     guess=female   name=Quigly
# correct=male     guess=female   name=Ragnar
# correct=male     guess=female   name=Rand
# correct=male     guess=female   name=Randal
# correct=male     guess=female   name=Randall
# correct=male     guess=female   name=Ravi
# correct=male     guess=female   name=Raymond
# correct=male     guess=female   name=Renault
# correct=male     guess=female   name=Rene
# correct=male     guess=female   name=Reza
# correct=male     guess=female   name=Rhett
# correct=male     guess=female   name=Rick
# correct=male     guess=female   name=Rob
# correct=male     guess=female   name=Robin
# correct=male     guess=female   name=Rodd
# correct=male     guess=female   name=Rolland
# correct=male     guess=female   name=Rourke
# correct=male     guess=female   name=Roy
# correct=male     guess=female   name=Royce
# correct=male     guess=female   name=Rudolf
# correct=male     guess=female   name=Rudy
# correct=male     guess=female   name=Russel
# correct=male     guess=female   name=Salim
# correct=male     guess=female   name=Sandor
# correct=male     guess=female   name=Saxon
# correct=male     guess=female   name=Schroeder
# correct=male     guess=female   name=Scot
# correct=male     guess=female   name=Seamus
# correct=male     guess=female   name=Shaw
# correct=male     guess=female   name=Shayne
# correct=male     guess=female   name=Sheff
# correct=male     guess=female   name=Shepherd
# correct=male     guess=female   name=Skelly
# correct=male     guess=female   name=Sonny
# correct=male     guess=female   name=Spud
# correct=male     guess=female   name=Staffard
# correct=male     guess=female   name=Stearn
# correct=male     guess=female   name=Stuart
# correct=male     guess=female   name=Sturgis
# correct=male     guess=female   name=Sunny
# correct=male     guess=female   name=Terence
# correct=male     guess=female   name=Terrance
# correct=male     guess=female   name=Thaddius
# correct=male     guess=female   name=Tharen
# correct=male     guess=female   name=Theobald
# correct=male     guess=female   name=Thibaut
# correct=male     guess=female   name=Thorndike
# correct=male     guess=female   name=Thornton
# correct=male     guess=female   name=Thorpe
# correct=male     guess=female   name=Timmy
# correct=male     guess=female   name=Tobe
# correct=male     guess=female   name=Torrence
# correct=male     guess=female   name=Town
# correct=male     guess=female   name=Travis
# correct=male     guess=female   name=Tremain
# correct=male     guess=female   name=Trever
# correct=male     guess=female   name=Urbanus
# correct=male     guess=female   name=Valentine
# correct=male     guess=female   name=Vernon
# correct=male     guess=female   name=Vilhelm
# correct=male     guess=female   name=Vinny
# correct=male     guess=female   name=Vite
# correct=male     guess=female   name=Walt
# correct=male     guess=female   name=Weber
# correct=male     guess=female   name=Wendall
# correct=male     guess=female   name=Whit
# correct=male     guess=female   name=Wilbert
# correct=male     guess=female   name=Wilton
# correct=male     guess=female   name=Winnie
# correct=male     guess=female   name=Woodman
# correct=male     guess=female   name=Woodrow
# correct=male     guess=female   name=Wylie
# correct=male     guess=female   name=Yacov
# correct=male     guess=female   name=Yancy
# correct=male     guess=female   name=Yves
# correct=male     guess=female   name=Zary
# correct=male     guess=female   name=Zolly

# %% [markdown]
# # Part 2

# %%
### classify documents based on keywords
from nltk.corpus import movie_reviews
import random

# movie reviews are labeled either positive or negative (by human annotators)
print(movie_reviews.categories())

# for each document in movie_reviews, get its words and category (positive/negative)
documents = [(list(movie_reviews.words(fileid)), category)
              for category in movie_reviews.categories()
              for fileid in movie_reviews.fileids(category)]
print(len(documents))

random.shuffle(documents)
# look at the first document - consists of a list of all the words in the review
# followed by the category
print(documents[0])

## use words from all documents to define the word vector for features
# get all words from all movie_reviews and put into a frequency distribution
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
print(len(all_words))
# Out:
# ['neg', 'pos']
# 2000
# (['i', 'had', 'an', 'epiphany', 'today', '.', 'it', 'occurred', 'to', 'me', 'while', 'i', 'was', 'watching', '"', 'house', 'on', 'haunted', 'hill', '.', '"', 'it', 'is', 'as', 'follows', ':', 'if', 'a', 'trailer', 'makes', 'the', 'film', 'it', "'", 's', 'advertising', 'look', 'like', 'a', 'trashy', ',', 'stupid', 'movie', ',', 'well', 'guess', 'what', '?', 'chances', 'are', ',', 'there', '*', 'is', '*', 'truth', 'in', 'advertising', '.', 'too', 'bad', 'i', 'didn', "'", 't', 'trust', 'my', 'own', 'instincts', 'when', 'something', '-', 'or', '-', 'the', '-', 'other', 'possessed', 'me', 'to', 'see', 'this', 'movie', '.', 'i', 'blame', 'it', 'on', 'my', 'sudden', 'craving', 'for', 'a', 'scare', 'and', 'my', 'anticipation', 'of', '"', 'sleepy', 'hollow', '.', '"', 'that', 'and', '"', 'dogma', '"', 'started', 'too', 'late', 'in', 'the', 'afternoon', 'for', 'my', 'schedule', '.', 'an', 'hour', 'of', '"', 'angel', '"', 'or', '"', 'buffy', '"', 'is', 'scarier', 'than', 'this', 'doozy', 'that', 'tries', 'to', 'be', 'scary', 'and', 'shtick', 'but', 'falls', 'flat', 'on', 'its', 'face', '.', 'i', 'wish', 'i', "'", 'd', 'seen', 'it', 'when', 'it', 'was', 'halloween', '.', 'at', 'least', 'i', 'would', 'have', 'been', 'forgiving', '.', 'hey', ',', 'tis', 'the', 'season', '.', 'the', 'movie', 'was', 'scary', '(', 'albeit', 'very', 'confusing', ',', 'dizzying', ',', 'and', 'nauseating', ')', 'at', 'first', ',', 'but', 'soon', 'the', 'horror', 'got', 'repetitive', 'and', 'downright', 'laughable', 'because', 'the', 'film', 'obviously', 'wasn', "'", 't', 'going', 'anywhere', '.', 'now', 'i', 'truly', 'appreciate', 'films', 'like', '"', 'scream', ',', '"', '"', 'halloween', ',', '"', 'or', 'any', 'old', 'hitchcock', 'film', 'where', 'the', 'scariness', 'stems', 'from', 'situations', 'that', 'are', 'at', 'least', 'somewhat', 'realistic', '.', 'that', "'", 's', 'what', 'spooks', 'people', 'out', ',', 'the', 'fact', 'that', 'it', 'could', 'happen', 'to', 'them', 'or', 'someone', 'they', 'know', '.', 'there', 'has', 'to', 'be', 'a', 'logical', 'precedent', 'for', 'the', 'situations', 'they', 'want', 'to', 'scare', 'us', 'with', '.', 'sure', ',', 'utterly', 'unpredictable', 'is', 'good', ',', 'too', ',', 'but', 'that', "'", 's', 'different', 'from', 'utterly', 'nonsensical', '.', 'hohh', '(', 'house', 'on', 'haunted', 'hill', ')', ',', 'on', 'the', 'other', 'hand', '.', '.', '.', 'well', 'let', "'", 's', 'just', 'say', 'i', 'about', 'fell', 'off', 'my', 'chair', 'laughing', 'when', 'they', 'oh', '-', 'so', '-', 'cleverly', 'revealed', 'that', 'everyone', 'who', 'got', 'invited', 'to', 'the', 'party', 'was', 'related', 'to', 'the', 'psycho', 'doctors', 'who', 'died', 'in', 'the', 'house', 'a', 'couple', 'of', 'decades', 'ago', '.', 'riiiiight', '.', 'y', "'", 'know', ',', 'that', 'just', 'sends', 'chills', 'down', 'my', 'spine', '.', 'yeah', '.', 'just', 'like', 'i', 'wet', 'my', 'pants', 'when', 'they', 'told', 'me', 'the', 'house', 'is', 'evil', '.', 'ooooooo', '.', 'hint', ':', 'blood', 'and', 'guts', 'only', 'work', 'a', 'few', 'times', '.', 'sooner', 'or', 'later', 'people', 'start', 'to', 'tell', 'themselves', 'that', 'it', "'", 's', 'just', 'ketchup', 'and', 'props', 'and', 'you', "'", 've', 'got', 'to', 'come', 'up', 'with', 'something', 'better', 'than', 'that', '.', 'there', 'were', 'just', 'too', 'many', 'things', 'in', 'this', 'movie', 'that', 'we', "'", 've', 'all', 'seen', 'before', ';', 'from', 'the', 'inevitable', '"', 'plot', 'developments', '"', 'of', 'strangers', 'unwittingly', 'trapped', 'together', ';', 'strangers', 'turning', 'against', 'each', 'other', ';', 'the', 'evil', 'manifesting', 'itself', ';', 'the', 'dead', 'coming', 'back', 'for', 'a', 'last', 'scare', '.', 'each', 'was', 'more', 'predictable', 'than', 'the', 'last', '.', 'why', 'didn', "'", 't', 'these', 'fools', 'just', 'stay', 'together', 'in', 'one', 'place', 'anyways', '?', 'sheesh', '.', 'was', 'i', 'grossed', 'out', '?', 'yes', '.', 'did', 'i', 'get', 'spooked', ' ...
# 39768

# %%
# get the 2000 most frequently appearing keywords in the corpus
word_items = all_words.most_common(2000)
word_features = [word for (word, freq) in word_items]   # just the words

# look at the first 100 words
# print(word_features[:100])

# define features (keywords) of a document
# each feature is 'contains(keyword)' and is true or false depending
# on whether that keyword is in the document
def document_features(document, word_features):
	document_words = set(document)
	features = {}
	for word in word_features:
		features['V_%s' % word] = (word in document_words)
	return features

# get features sets for a document, including keyword features and category feature
featuresets = [(document_features(d, word_features), c) for (d,c) in documents]

# the feature sets are 2000 words long - so this is optional
# print(featuresets[0])

# training using naive Baysian classifier with a 95/5 split
train_set, test_set = featuresets[100:], featuresets[:100]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# evaluate the accuracy of the classifier
print (nltk.classify.accuracy(classifier, test_set))
# the accuracy result may vary since we randomized the documents

# show which features of classifier are most informative
print(classifier.show_most_informative_features(30))
# Out:
# 0.78
# Most Informative Features
#                 V_seagal = True              neg : pos    =     11.5 : 1.0
#            V_outstanding = True              pos : neg    =     11.0 : 1.0
#                  V_mulan = True              pos : neg    =      9.1 : 1.0
#            V_wonderfully = True              pos : neg    =      6.9 : 1.0
#                  V_damon = True              pos : neg    =      6.8 : 1.0
#                  V_awful = True              neg : pos    =      5.9 : 1.0
#                   V_lame = True              neg : pos    =      5.5 : 1.0
#                 V_wasted = True              neg : pos    =      5.3 : 1.0
#                  V_waste = True              neg : pos    =      5.2 : 1.0
#             V_ridiculous = True              neg : pos    =      5.1 : 1.0
#                  V_flynt = True              pos : neg    =      5.1 : 1.0
#                 V_poorly = True              neg : pos    =      4.8 : 1.0
#                    V_era = True              pos : neg    =      4.5 : 1.0
#                  V_worst = True              neg : pos    =      4.3 : 1.0
#                  V_bland = True              neg : pos    =      4.2 : 1.0
#                V_unfunny = True              neg : pos    =      4.2 : 1.0
#              V_fantastic = True              pos : neg    =      4.1 : 1.0
#                   V_mess = True              neg : pos    =      4.0 : 1.0
#                 V_allows = True              pos : neg    =      4.0 : 1.0
#              V_pointless = True              neg : pos    =      3.9 : 1.0
#                   V_dull = True              neg : pos    =      3.8 : 1.0
#                 V_stupid = True              neg : pos    =      3.8 : 1.0
#              V_portrayal = True              pos : neg    =      3.7 : 1.0
#                   V_jedi = True              pos : neg    =      3.7 : 1.0
#              V_laughable = True              neg : pos    =      3.7 : 1.0
#              V_portrayed = True              pos : neg    =      3.7 : 1.0
#                 V_superb = True              pos : neg    =      3.7 : 1.0
#              V_memorable = True              pos : neg    =      3.6 : 1.0
#               V_terrific = True              pos : neg    =      3.6 : 1.0
#                 V_boring = True              neg : pos    =      3.5 : 1.0
# None

# %%
import numpy as np
for i in np.arange(1000, 3000, 200):
    # get the 2000 most frequently appearing keywords in the corpus
    word_items = all_words.most_common(i)
    word_features = [word for (word, freq) in word_items]   # just the words

    # look at the first 100 words
    # print(word_features[:100])

    # define features (keywords) of a document
    # each feature is 'contains(keyword)' and is true or false depending
    # on whether that keyword is in the document
    def document_features(document, word_features):
        document_words = set(document)
        features = {}
        for word in word_features:
            features['V_%s' % word] = (word in document_words)
        return features

    # get features sets for a document, including keyword features and category feature
    featuresets = [(document_features(d, word_features), c) for (d,c) in documents]

    # the feature sets are 2000 words long - so this is optional
    # print(featuresets[0])

    # training using naive Baysian classifier with a 95/5 split
    train_set, test_set = featuresets[100:], featuresets[:100]
    classifier = nltk.NaiveBayesClassifier.train(train_set)

    # evaluate the accuracy of the classifier
    print ("Num Words: ", i, " Accuracy: ", nltk.classify.accuracy(classifier, test_set))
    # the accuracy result may vary since we randomized the documents

    # show which features of classifier are most informative
    # print(classifier.show_most_informative_features(30))
